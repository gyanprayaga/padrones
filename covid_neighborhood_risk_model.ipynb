# %%
#!/usr/bin/env python
# coding: utf-8

import pandas
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

## These bands are helpful for visualization
def cni_bands(CNI):
    if CNI > 1 and CNI <=1.7 :
        return 1.0
    elif CNI >1.7 and CNI <=2.5 :
        return 2.0
    elif CNI >2.5 and CNI <=3.3 :
        return 3.0
    elif CNI >3.3 and CNI <=4.1 :
        return 4.0
    elif CNI >4.1 :
        return 5.0

#we will be using the GINI decision tree model
def train_using_gini(X_train, X_test, y_train):

    # Creating the classifier object
    clf_gini = DecisionTreeClassifier(criterion = "gini",
                                      random_state = 100,max_depth=3, min_samples_leaf=5)
    # Performing training
    clf_gini.fit(X_train, y_train)
    return clf_gini

# use this function to do the prediction
def prediction(X_test, clf_object):
    # Prediction on test with giniIndex
    y_pred = clf_object.predict(X_test)
    return y_pred

# Function to calculate accuracy
def cal_accuracy(y_test, y_pred):

    print("Confusion Matrix: ",
    confusion_matrix(y_test, y_pred))
    print ("Accuracy : ",
    accuracy_score(y_test,y_pred)*100)
    print("Report : ",
    classification_report(y_test, y_pred))

def covid_risk_bands_v2(covid_change_rate_multiplied):
    if covid_change_rate_multiplied < 0.013081 :
        return "Low risk"
    if covid_change_rate_multiplied < 0.075136 :
        return "Medium risk"
    if covid_change_rate_multiplied < 0.299020 :
        return "High risk"
    elif covid_change_rate_multiplied >= 0.299020 :
        return "Very high risk"
    else :
        return "Unknown"

## based ona a zip, return the predicted score
def get_risk_for_zip(zip):

    if len(lac_zips[lac_zips['Zip Code'] == zip]) == 0 :
        print (str(zip) + "Not in Los Angeles")
        return "Unknown"

    elif (len(lacounty_today[lacounty_today['zip_code'] == zip]) >= 1) :
        print ("Found an existing city with Covid Data for " + str(zip) )
        x = lacounty_today[lacounty_today['zip_code'] == zip]
        data= [[x.iloc[0]['population'],x.iloc[0]['cni'], x.iloc[0]['covid_change_rate_multiplied']]]
    
    else :
        x = lac_zips[lac_zips['Zip Code'] == zip]
        # check our data to see if the place matches something we already know
        print ("Need to find Zip level data" + str(zip))
        y = lacounty_today[lacounty_today['place'] == x.iloc[0]['City']]
        if len(y) > 0 :
            # use that city/place's values instead
            data= [[y.iloc[0]['population'],y.iloc[0]['cni'], y.iloc[0]['covid_change_rate_multiplied']]]
            print ("using " + y.iloc[0]['place'] + ' data to get the risk')
        else :
            data = [[x.iloc[0]['Population'],x.iloc[0]['CNI'], 0.0]]
    
    data = pandas.DataFrame(data, columns = ['population', 'cni', 'covid_change_rate_multiplied'])
    zip_pred = prediction(data, clf_gini)
    
    return (zip_pred[0])

# %%
## Get all data available
## lots of preprocessing done within the Excel sheets - can be converted to Pandas
lacounty_data = pandas.read_excel("CovidData.xlsx", sheet_name="LACCovidData")

# clean the Data
lacounty_data = lacounty_data.fillna(0)
lacounty_data['Zip code']=lacounty_data['Zip code'].fillna(0)
lacounty_data['Zip code']=lacounty_data['Zip code'].astype(int)

# %%
lac_zips = pandas.read_excel("CovidData.xlsx", sheet_name="LACZipsPopCNI")

# %%
#Get the latest data
lacounty_today = lacounty_data.groupby('place').agg(
    place = ('place', 'max'),
    zip_code = ('Zip code', 'max'),
    covid_rate = ('Covid Rate', 'max'),
    population = ('Population', 'max'),
    confirmed_cases = ('confirmed_cases', 'max') ,
    cni = ('CNI','max'),
    covid_change_rate = ('Covid Change Rate', 'mean')
    )

lacounty_today['covid_change_rate_multiplied'] = lacounty_today['covid_change_rate'] * lacounty_today['covid_rate'] * 1000

# %%
# lacounty_today.corr(method ='spearman')
# this correlation is high between CNI and covid_change_rate_multiplied

lacounty_today['cni_bands'] = lacounty_today['cni'].apply(cni_bands)
lacounty_today['covid_risk_bands'] = lacounty_today['covid_change_rate_multiplied'].apply(covid_risk_bands_v2)

# %%
## set up the data for training
X = lacounty_today[['population','cni', 'covid_change_rate_multiplied']]
Y = lacounty_today['covid_risk_bands']

## setting up the training the train/test (70/30 split)
X_train, X_test, y_train, y_test = train_test_split(
          X, Y, test_size = 0.3, random_state = 100)

# imputing missing values with the means
X_test = X_test.fillna(X_test.mean())
X_train = X_train.fillna(X_train.mean())
clf_gini = train_using_gini(X_train, X_test, y_train)
y_pred_gini = prediction(X_test, clf_gini)
cal_accuracy(y_test, y_pred_gini)
# Out:
# Predicted values:
# ['High risk' 'Medium risk' 'Low risk' 'Very high risk' 'High risk'
#  'Medium risk' 'Very high risk' 'Medium risk' 'Low risk' 'Very high risk'
#  'Low risk' 'Low risk' 'Very high risk' 'Very high risk' 'Very high risk'
#  'Medium risk' 'Medium risk' 'Very high risk' 'Low risk' 'Medium risk'
#  'Low risk' 'Medium risk' 'Very high risk' 'Very high risk' 'Medium risk'
#  'Very high risk' 'Very high risk' 'Medium risk' 'High risk' 'High risk'
#  'High risk' 'Medium risk' 'High risk' 'Medium risk' 'Low risk'
#  'High risk' 'Very high risk' 'Low risk' 'Low risk' 'High risk' 'Low risk'
#  'Low risk' 'Very high risk' 'Low risk' 'High risk' 'Low risk' 'Low risk'
#  'Low risk' 'Low risk' 'High risk' 'High risk' 'High risk'
#  'Very high risk' 'High risk' 'High risk' 'Low risk' 'Medium risk'
#  'Very high risk' 'High risk' 'Low risk' 'High risk' 'High risk'
#  'High risk' 'Low risk' 'Medium risk' 'Medium risk' 'Medium risk'
#  'Very high risk' 'Very high risk' 'Medium risk' 'High risk' 'High risk'
#  'Medium risk' 'Medium risk' 'High risk' 'High risk' 'Very high risk'
#  'Medium risk' 'High risk' 'Very high risk' 'Low risk' 'Low risk'
#  'Very high risk' 'High risk' 'Low risk' 'Low risk' 'Very high risk'
#  'Very high risk' 'Medium risk' 'Low risk' 'Very high risk'
#  'Very high risk' 'Very high risk' 'High risk' 'Medium risk' 'Low risk'
#  'Low risk']
# Confusion Matrix:  [[24  0  0  0]
#  [ 0 25  0  0]
#  [ 0  1 21  0]
#  [ 1  0  0 25]]
# Accuracy :  97.9381443298969
# Report :                  precision    recall  f1-score   support
#
#      High risk       0.96      1.00      0.98        24
#       Low risk       0.96      1.00      0.98        25
#    Medium risk       1.00      0.95      0.98        22
# Very high risk       1.00      0.96      0.98        26
#
#       accuracy                           0.98        97
#      macro avg       0.98      0.98      0.98        97
#   weighted avg       0.98      0.98      0.98        97

# %%
lac_zips_all = pandas.read_excel("CovidData.xlsx", sheet_name="LAC Zips")
lac_zips_all = lac_zips_all.replace(to_replace = r"ZIP Code ", value = "", regex=True)
lac_zips_all['ZIP Code'] = lac_zips_all['ZIP Code'].astype(int)

# %%
lac_zips_all.head()
# Out:
#    ZIP Code Classification         City  Population Timezone  \
# 0     90001        General  Los Angeles       57110  Pacific
# 1     90002        General  Los Angeles       51223  Pacific
# 2     90003        General  Los Angeles       66266  Pacific
# 3     90004        General  Los Angeles       62180  Pacific
# 4     90005        General  Los Angeles       37681  Pacific
#
#           Area Code(s)
# 0                  323
# 1              323/562
# 2              323/213
# 3              323/213
# 4  323/213/310/818/626

# %%
lac_zips_all['covid_risk_risk'] = lac_zips_all['ZIP Code'].apply(get_risk_for_zip)
# Out:
# Found an existing city with Covid Data for 90001
# Found an existing city with Covid Data for 90002
# Found an existing city with Covid Data for 90003
# Found an existing city with Covid Data for 90004
# Need to find Zip level data90005
# Found an existing city with Covid Data for 90006
# Found an existing city with Covid Data for 90007
# Found an existing city with Covid Data for 90008
# 90009Not in Los Angeles
# Need to find Zip level data90010
# Found an existing city with Covid Data for 90011
# Found an existing city with Covid Data for 90012
# Found an existing city with Covid Data for 90013
# Found an existing city with Covid Data for 90014
# Need to find Zip level data90015
# Found an existing city with Covid Data for 90016
# Need to find Zip level data90017
# Found an existing city with Covid Data for 90018
# Found an existing city with Covid Data for 90019
# Found an existing city with Covid Data for 90020
# Need to find Zip level data90021
# Found an existing city with Covid Data for 90022
# Need to find Zip level data90023
# Found an existing city with Covid Data for 90024
# Found an existing city with Covid Data for 90025
# Found an existing city with Covid Data for 90026
# Found an existing city with Covid Data for 90027
# Need to find Zip level data90028
# Found an existing city with Covid Data for 90029
# 90030Not in Los Angeles
# Found an existing city with Covid Data for 90031
# Found an existing city with Covid Data for 90032
# Found an existing city with Covid Data for 90033
# Found an existing city with Covid Data for 90034
# Found an existing city with Covid Data for 90035
# Found an existing city with Covid Data for 90036
# Found an existing city with Covid Data for 90037
# Need to find Zip level data90038
# Found an existing city with Covid Data for 90039
# Found an existing city with Covid Data for 90040
# Found an existing city with Covid Data for 90041
# Found an existing city with Covid Data for 90042
# Found an existing city with Covid Data for 90043
# Found an existing city with Covid Data for 90044
# Found an existing city with Covid Data for 90045
# Found an existing city with Covid Data for 90046
# Found an existing city with Covid Data for 90047
# Found an existing city with Covid Data for 90048
# Found an existing city with Covid Data for 90049
# 90050Not in Los Angeles
# 90051Not in Los Angeles
# 90052Not in Los Angeles
# 90053Not in Los Angeles
# 90054Not in Los Angeles
# 90055Not in Los Angeles
# Found an existing city with Covid Data for 90056
# Found an existing city with Covid Data for 90057
# Found an existing city with Covid Data for 90058
# Need to find Zip level data90059
# 90060Not in Los Angeles
# Found an existing city with Covid Data for 90061
# Need to find Zip level data90062
# Need to find Zip level data90063
# Found an existing city with Covid Data for 90064
# Found an existing city with Covid Data for 90065
# Found an existing city with Covid Data for 90066
# Need to find Zip level data90067
# Found an existing city with Covid Data for 90068
# Found an existing city with Covid Data for 90069
# 90070Not in Los Angeles
# Need to find Zip level data90071
# 90072Not in Los Angeles
# 90073Not in Los Angeles
# 90074Not in Los Angeles
# 90075Not in Los Angeles
# 90076Not in Los Angeles
# Found an existing city with Covid Data for 90077
# 90078Not in Los Angeles
# 90079Not in Los Angeles
# 90080Not in Los Angeles
# 90081Not in Los Angeles
# 90082Not in Los Angeles
# 90083Not in Los Angeles
# 90084Not in Los Angeles
# 90086Not in Los Angeles
# 90087Not in Los Angeles
# 90088Not in Los Angeles
# Need to find Zip level data90089
# 90090Not in Los Angeles
# 90091Not in Los Angeles
# 90093Not in Los Angeles
# Need to find Zip level data90094
# using Playa Vista data to get the risk
# Need to find Zip level data90095
# 90096Not in Los Angeles
# 90099Not in Los Angeles
# 90134Not in Los Angeles
# 90189Not in Los Angeles
# Found an existing city with Covid Data for 90201
# 90202Not in Los Angeles
# 90209Not in Los Angeles
# Found an existing city with Covid Data for 90210
# Need to find Zip level data90211
# using Beverly Hills data to get the risk
# Need to find Zip level data90212
# using Beverly Hills data to get the risk
# 90213Not in Los Angeles
# Found an existing city with Covid Data for 90220
# Found an existing city with Covid Data for 90221
# Found an existing city with Covid Data for 90222
# 90223Not in Los Angeles
# 90224Not in Los Angeles
# Found an existing city with Covid Data for 90230
# 90231Not in Los Angeles
# Need to find Zip level data90232
# using Culver City data to get the risk
# 90233Not in Los Angeles
# 90239Not in Los Angeles
# Need to find Zip level data90240
# using Downey data to get the risk
# Found an existing city with Covid Data for 90241
# Need to find Zip level data90242
# using Downey data to get the risk
# Found an existing city with Covid Data for 90245
# Found an existing city with Covid Data for 90247
# Found an existing city with Covid Data for 90248
# Found an existing city with Covid Data for 90249
# Found an existing city with Covid Data for 90250
# 90251Not in Los Angeles
# Found an existing city with Covid Data for 90254
# Found an existing city with Covid Data for 90255
# Found an existing city with Covid Data for 90260
# 90261Not in Los Angeles
# Found an existing city with Covid Data for 90262
# Need to find Zip level data90263
# using Malibu data to get the risk
# 90264Not in Los Angeles
# Found an existing city with Covid Data for 90265
# Found an existing city with Covid Data for 90266
# 90267Not in Los Angeles
# Found an existing city with Covid Data for 90270
# Found an existing city with Covid Data for 90272
# Found an existing city with Covid Data for 90274
# Found an existing city with Covid Data for 90275
# Need to find Zip level data90277
# using Redondo Beach data to get the risk
# Found an existing city with Covid Data for 90278
# Found an existing city with Covid Data for 90280
# Need to find Zip level data90290
# Found an existing city with Covid Data for 90291
# Found an existing city with Covid Data for 90292
# Found an existing city with Covid Data for 90293
# 90294Not in Los Angeles
# 90295Not in Los Angeles
# 90296Not in Los Angeles
# Found an existing city with Covid Data for 90301
# Need to find Zip level data90302
# using Inglewood data to get the risk
# Need to find Zip level data90303
# using Inglewood data to get the risk
# Found an existing city with Covid Data for 90304
# Need to find Zip level data90305
# using Inglewood data to get the risk
# 90306Not in Los Angeles
# 90307Not in Los Angeles
# 90308Not in Los Angeles
# 90309Not in Los Angeles
# 90310Not in Los Angeles
# 90311Not in Los Angeles
# 90312Not in Los Angeles
# Need to find Zip level data90401
# using Santa Monica data to get the risk
# Need to find Zip level data90402
# using Santa Monica data to get the risk
# Found an existing city with Covid Data for 90403
# Found an existing city with Covid Data for 90404
# Need to find Zip level data90405
# using Santa Monica data to get the risk
# 90406Not in Los Angeles
# 90407Not in Los Angeles
# 90408Not in Los Angeles
# 90409Not in Los Angeles
# 90410Not in Los Angeles
# 90411Not in Los Angeles
# Need to find Zip level data90501
# using Torrance data to get the risk
# Found an existing city with Covid Data for 90502
# Found an existing city with Covid Data for 90503
# Need to find Zip level data90504
# using Torrance data to get the risk
# Need to find Zip level data90505
# using Torrance data to get the risk
# 90506Not in Los Angeles
# 90507Not in Los Angeles
# 90508Not in Los Angeles
# 90509Not in Los Angeles
# 90510Not in Los Angeles
# Found an existing city with Covid Data for 90601
# Found an existing city with Covid Data for 90602
# Need to find Zip level data90603
# using Whittier data to get the risk
# Found an existing city with Covid Data for 90604
# Need to find Zip level data90605
# using Whittier data to get the risk
# Found an existing city with Covid Data for 90606
# 90607Not in Los Angeles
# 90608Not in Los Angeles
# 90609Not in Los Angeles
# 90610Not in Los Angeles
# 90637Not in Los Angeles
# Found an existing city with Covid Data for 90638
# 90639Not in Los Angeles
# Found an existing city with Covid Data for 90640
# Found an existing city with Covid Data for 90650
# 90651Not in Los Angeles
# 90652Not in Los Angeles
# Found an existing city with Covid Data for 90660
# 90661Not in Los Angeles
# 90662Not in Los Angeles
# Found an existing city with Covid Data for 90670
# 90671Not in Los Angeles
# Found an existing city with Covid Data for 90701
# 90702Not in Los Angeles
# Found an existing city with Covid Data for 90703
# 90704Not in Los Angeles
# Found an existing city with Covid Data for 90706
# 90707Not in Los Angeles
# Found an existing city with Covid Data for 90710
# 90711Not in Los Angeles
# Need to find Zip level data90712
# using Lakewood data to get the risk
# Found an existing city with Covid Data for 90713
# 90714Not in Los Angeles
# Need to find Zip level data90715
# using Lakewood data to get the risk
# Found an existing city with Covid Data for 90716
# Found an existing city with Covid Data for 90717
# Found an existing city with Covid Data for 90723
# Found an existing city with Covid Data for 90731
# Found an existing city with Covid Data for 90732
# 90733Not in Los Angeles
# 90734Not in Los Angeles
# Found an existing city with Covid Data for 90744
# Need to find Zip level data90745
# using Carson data to get the risk
# Found an existing city with Covid Data for 90746
# 90747Not in Los Angeles
# 90748Not in Los Angeles
# 90749Not in Los Angeles
# Found an existing city with Covid Data for 90755
# 90801Not in Los Angeles
# Need to find Zip level data90802
# using Long Beach data to get the risk
# Need to find Zip level data90803
# using Long Beach data to get the risk
# Need to find Zip level data90804
# using Long Beach data to get the risk
# Need to find Zip level data90805
# using Long Beach data to get the risk
# Found an existing city with Covid Data for 90806
# Need to find Zip level data90807
# using Long Beach data to get the risk
# Need to find Zip level data90808
# using Long Beach data to get the risk
# 90809Not in Los Angeles
# Need to find Zip level data90810
# using Long Beach data to get the risk
# Need to find Zip level data90813
# using Long Beach data to get the risk
# Need to find Zip level data90814
# using Long Beach data to get the risk
# Need to find Zip level data90815
# using Long Beach data to get the risk
# Need to find Zip level data90822
# using Long Beach data to get the risk
# 90831Not in Los Angeles
# 90832Not in Los Angeles
# 90833Not in Los Angeles
# 90840Not in Los Angeles
# 90842Not in Los Angeles
# 90844Not in Los Angeles
# 90846Not in Los Angeles
# 90847Not in Los Angeles
# 90848Not in Los Angeles
# 90853Not in Los Angeles
# 90895Not in Los Angeles
# Found an existing city with Covid Data for 91001
# 91003Not in Los Angeles
# Found an existing city with Covid Data for 91006
# Found an existing city with Covid Data for 91007
# Found an existing city with Covid Data for 91008
# 91009Not in Los Angeles
# Found an existing city with Covid Data for 91010
# Found an existing city with Covid Data for 91011
# 91012Not in Los Angeles
# Found an existing city with Covid Data for 91016
# 91017Not in Los Angeles
# Need to find Zip level data91020
# 91021Not in Los Angeles
# 91023Not in Los Angeles
# Found an existing city with Covid Data for 91024
# 91025Not in Los Angeles
# Found an existing city with Covid Data for 91030
# 91031Not in Los Angeles
# Found an existing city with Covid Data for 91040
# 91041Not in Los Angeles
# Found an existing city with Covid Data for 91042
# 91043Not in Los Angeles
# 91046Not in Los Angeles
# 91066Not in Los Angeles
# 91077Not in Los Angeles
# Need to find Zip level data91101
# using Pasadena data to get the risk
# 91102Not in Los Angeles
# Need to find Zip level data91103
# using Pasadena data to get the risk
# Found an existing city with Covid Data for 91104
# Need to find Zip level data91105
# using Pasadena data to get the risk
# Need to find Zip level data91106
# using Pasadena data to get the risk
# Found an existing city with Covid Data for 91107
# Found an existing city with Covid Data for 91108
# 91109Not in Los Angeles
# 91110Not in Los Angeles
# 91114Not in Los Angeles
# 91115Not in Los Angeles
# 91116Not in Los Angeles
# 91117Not in Los Angeles
# 91118Not in Los Angeles
# 91121Not in Los Angeles
# 91123Not in Los Angeles
# 91124Not in Los Angeles
# 91125Not in Los Angeles
# 91126Not in Los Angeles
# 91129Not in Los Angeles
# 91182Not in Los Angeles
# 91184Not in Los Angeles
# 91185Not in Los Angeles
# 91188Not in Los Angeles
# 91189Not in Los Angeles
# 91199Not in Los Angeles
# Need to find Zip level data91201
# using Glendale data to get the risk
# Need to find Zip level data91202
# using Glendale data to get the risk
# Need to find Zip level data91203
# using Glendale data to get the risk
# Need to find Zip level data91204
# using Glendale data to get the risk
# Need to find Zip level data91205
# using Glendale data to get the risk
# Need to find Zip level data91206
# using Glendale data to get the risk
# Need to find Zip level data91207
# using Glendale data to get the risk
# Found an existing city with Covid Data for 91208
# 91209Not in Los Angeles
# Need to find Zip level data91210
# using Glendale data to get the risk
# Found an existing city with Covid Data for 91214
# 91221Not in Los Angeles
# 91222Not in Los Angeles
# 91224Not in Los Angeles
# 91225Not in Los Angeles
# 91226Not in Los Angeles
# Found an existing city with Covid Data for 91301
# Found an existing city with Covid Data for 91302
# Need to find Zip level data91303
# using Canoga Park data to get the risk
# Found an existing city with Covid Data for 91304
# 91305Not in Los Angeles
# Found an existing city with Covid Data for 91306
# Need to find Zip level data91307
# using West Hills data to get the risk
# 91308Not in Los Angeles
# 91309Not in Los Angeles
# 91310Not in Los Angeles
# Found an existing city with Covid Data for 91311
# 91313Not in Los Angeles
# Found an existing city with Covid Data for 91316
# Found an existing city with Covid Data for 91321
# 91322Not in Los Angeles
# Need to find Zip level data91324
# using Northridge data to get the risk
# Found an existing city with Covid Data for 91325
# Found an existing city with Covid Data for 91326
# 91327Not in Los Angeles
# 91328Not in Los Angeles
# 91329Not in Los Angeles
# Need to find Zip level data91330
# using Northridge data to get the risk
# Found an existing city with Covid Data for 91331
# 91333Not in Los Angeles
# 91334Not in Los Angeles
# Found an existing city with Covid Data for 91335
# 91337Not in Los Angeles
# Found an existing city with Covid Data for 91340
# 91341Not in Los Angeles
# Found an existing city with Covid Data for 91342
# Found an existing city with Covid Data for 91343
# Found an existing city with Covid Data for 91344
# Found an existing city with Covid Data for 91345
# 91346Not in Los Angeles
# Need to find Zip level data91350
# using Santa Clarita data to get the risk
# Found an existing city with Covid Data for 91351
# Found an existing city with Covid Data for 91352
# 91353Not in Los Angeles
# Found an existing city with Covid Data for 91354
# Need to find Zip level data91355
# using Valencia data to get the risk
# Found an existing city with Covid Data for 91356
# 91357Not in Los Angeles
# Found an existing city with Covid Data for 91364
# 91365Not in Los Angeles
# Need to find Zip level data91367
# using Woodland Hills data to get the risk
# Need to find Zip level data91371
# using Woodland Hills data to get the risk
# 91372Not in Los Angeles
# 91376Not in Los Angeles
# 91380Not in Los Angeles
# Found an existing city with Covid Data for 91381
# 91382Not in Los Angeles
# 91383Not in Los Angeles
# Found an existing city with Covid Data for 91384
# 91385Not in Los Angeles
# 91386Not in Los Angeles
# Need to find Zip level data91387
# using Canyon Country data to get the risk
# Found an existing city with Covid Data for 91390
# 91392Not in Los Angeles
# 91393Not in Los Angeles
# 91394Not in Los Angeles
# 91395Not in Los Angeles
# 91396Not in Los Angeles
# Found an existing city with Covid Data for 91401
# Found an existing city with Covid Data for 91402
# Need to find Zip level data91403
# using Sherman Oaks data to get the risk
# 91404Not in Los Angeles
# Found an existing city with Covid Data for 91405
# Found an existing city with Covid Data for 91406
# 91407Not in Los Angeles
# 91408Not in Los Angeles
# 91409Not in Los Angeles
# 91410Not in Los Angeles
# Need to find Zip level data91411
# using Van Nuys data to get the risk
# 91412Not in Los Angeles
# 91413Not in Los Angeles
# 91416Not in Los Angeles
# Found an existing city with Covid Data for 91423
# 91426Not in Los Angeles
# Need to find Zip level data91436
# using Encino data to get the risk
# 91470Not in Los Angeles
# 91482Not in Los Angeles
# 91495Not in Los Angeles
# 91496Not in Los Angeles
# 91499Not in Los Angeles
# Need to find Zip level data91501
# using Burbank data to get the risk
# Need to find Zip level data91502
# using Burbank data to get the risk
# 91503Not in Los Angeles
# Found an existing city with Covid Data for 91504
# Need to find Zip level data91505
# using Burbank data to get the risk
# Need to find Zip level data91506
# using Burbank data to get the risk
# 91507Not in Los Angeles
# 91508Not in Los Angeles
# 91510Not in Los Angeles
# 91521Not in Los Angeles
# 91522Not in Los Angeles
# 91523Not in Los Angeles
# 91526Not in Los Angeles
# Found an existing city with Covid Data for 91601
# Found an existing city with Covid Data for 91602
# 91603Not in Los Angeles
# Found an existing city with Covid Data for 91604
# Need to find Zip level data91605
# using North Hollywood data to get the risk
# Found an existing city with Covid Data for 91606
# Found an existing city with Covid Data for 91607
# 91608Not in Los Angeles
# 91609Not in Los Angeles
# 91610Not in Los Angeles
# 91611Not in Los Angeles
# 91612Not in Los Angeles
# 91614Not in Los Angeles
# 91615Not in Los Angeles
# 91616Not in Los Angeles
# 91617Not in Los Angeles
# 91618Not in Los Angeles
# Found an existing city with Covid Data for 91702
# Found an existing city with Covid Data for 91706
# Found an existing city with Covid Data for 91711
# 91714Not in Los Angeles
# 91715Not in Los Angeles
# 91716Not in Los Angeles
# Need to find Zip level data91722
# using Covina data to get the risk
# Found an existing city with Covid Data for 91723
# Found an existing city with Covid Data for 91724
# Found an existing city with Covid Data for 91731
# Need to find Zip level data91732
# using El Monte data to get the risk
# Found an existing city with Covid Data for 91733
# 91734Not in Los Angeles
# 91735Not in Los Angeles
# Need to find Zip level data91740
# using Glendora data to get the risk
# Found an existing city with Covid Data for 91741
# Found an existing city with Covid Data for 91744
# Found an existing city with Covid Data for 91745
# Found an existing city with Covid Data for 91746
# 91747Not in Los Angeles
# Found an existing city with Covid Data for 91748
# 91749Not in Los Angeles
# Found an existing city with Covid Data for 91750
# Found an existing city with Covid Data for 91754
# Need to find Zip level data91755
# using Monterey Park data to get the risk
# 91756Not in Los Angeles
# Found an existing city with Covid Data for 91765
# Found an existing city with Covid Data for 91766
# Need to find Zip level data91767
# using Pomona data to get the risk
# Found an existing city with Covid Data for 91768
# 91769Not in Los Angeles
# Found an existing city with Covid Data for 91770
# 91771Not in Los Angeles
# 91772Not in Los Angeles
# Found an existing city with Covid Data for 91773
# Found an existing city with Covid Data for 91775
# Found an existing city with Covid Data for 91776
# 91778Not in Los Angeles
# Found an existing city with Covid Data for 91780
# 91788Not in Los Angeles
# Found an existing city with Covid Data for 91789
# Need to find Zip level data91790
# using West Covina data to get the risk
# Found an existing city with Covid Data for 91791
# Need to find Zip level data91792
# using West Covina data to get the risk
# 91793Not in Los Angeles
# Need to find Zip level data91801
# using Alhambra data to get the risk
# 91802Not in Los Angeles
# Found an existing city with Covid Data for 91803
# 91804Not in Los Angeles
# 91896Not in Los Angeles
# 91899Not in Los Angeles
# Found an existing city with Covid Data for 93510
# Found an existing city with Covid Data for 93532
# Found an existing city with Covid Data for 93534
# Found an existing city with Covid Data for 93535
# Found an existing city with Covid Data for 93536
# 93539Not in Los Angeles
# Found an existing city with Covid Data for 93543
# Found an existing city with Covid Data for 93544
# Found an existing city with Covid Data for 93550
# Found an existing city with Covid Data for 93551
# Found an existing city with Covid Data for 93552
# Found an existing city with Covid Data for 93553
# Need to find Zip level data93563
# 93584Not in Los Angeles
# 93586Not in Los Angeles
# 93590Not in Los Angeles
# Need to find Zip level data93591
# using Palmdale data to get the risk
# 93599Not in Los Angeles

# %%
lac_zips_all.head()
# Out:
#    ZIP Code Classification         City  Population Timezone  \
# 0     90001        General  Los Angeles       57110  Pacific
# 1     90002        General  Los Angeles       51223  Pacific
# 2     90003        General  Los Angeles       66266  Pacific
# 3     90004        General  Los Angeles       62180  Pacific
# 4     90005        General  Los Angeles       37681  Pacific
#
#           Area Code(s) covid_risk_risk
# 0                  323  Very high risk
# 1              323/562       High risk
# 2              323/213     Medium risk
# 3              323/213     Medium risk
# 4  323/213/310/818/626        Low risk

# %%
get_risk_for_zip(90001)
# Out:
# Found an existing city with Covid Data for 90001
# 'Very high risk'

# %%
lac_zips_all.to_csv("lac_zips_risk.csv")
